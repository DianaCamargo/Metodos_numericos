# %%
# import math as mt
import matplotlib
import numpy as np
n=5
es=0.5*(10**(2-n))*100 #Error tolerado
print '######Ejemplo 5.4 Chapra#####\n Metodo biseccion \n ###Diana Camargo###'
print 'f(c)=(667.38/c)*(1-mt.e**(-0.146843*c)-40)'  
print 'Error Tolerado=', es, '%'
print 'ERPA=Error Relativo Porcentual Aproximado'
print ("_______________________________________________________________________________")
print "|%-5s | %-12s |   %-9s  |   %-9s  | %-9s  | %-9s  |" %('Iteraccion','    xi  ','   xu','  xr ',' ERPA (%)','ERPV (%)')
xi=12.0
xu=16.0
xr=0.0
fxi=0.0
fxu=0.0
vver=14.7802 #LA RAIZ Verdadera
i=1
erpa=0.0
val_ante=0.0
while(True):
    val_ante=xr
    fxi=((667.38/xi)*(1-mt.e**(-0.146843*xi)))-40
    fxu=((667.38/xu)*(1-mt.e**(-0.146843*xu)))-40
    xr=(xi+xu)/2
    fxr=((667.38/xr)*(1-mt.e**(-0.146843*xr)))-40
    ev=vver-xr
    erpv=abs(ev/vver)*100
    erpa=abs((xr-val_ante)/(xr))*100
    print ("__________________________________________________________________________________")
    print"|    %-6d |    %-9f |    %-9f |    %-9f |  %-10f|  %-10f|" %(i,xi,xu,xr,erpa,erpv)
    if(fxi*fxr<0):
        xu=xr
    if(fxi*fxr>0):
        xi=xr
    if (erpa<es or fxi*fxr==0):
        break
    i=i+1
print '\nValor Aproximado= ',xr
# Out:
# ######Ejemplo 5.4 Chapra#####
#  Metodo biseccion
#  ###Diana Camargo###
# f(x)=x^10  - 1
# Error Tolerado= 0.05 %
# ERPA=Error Relativo Porcentual Aproximado
# _______________________________________________________________________________
# |Iteraccion |     xi       |      xu      |     xr       |  ERPA (%)  | ERPV (%)   |
# __________________________________________________________________________________
# |    1      |    12.000000 |    16.000000 |    14.000000 |  100.000000|  5.278684  |
# __________________________________________________________________________________
# |    2      |    14.000000 |    16.000000 |    15.000000 |  6.666667  |  1.487125  |
# __________________________________________________________________________________
# |    3      |    14.000000 |    15.000000 |    14.500000 |  3.448276  |  1.895779  |
# __________________________________________________________________________________
# |    4      |    14.500000 |    15.000000 |    14.750000 |  1.694915  |  0.204327  |
# __________________________________________________________________________________
# |    5      |    14.750000 |    15.000000 |    14.875000 |  0.840336  |  0.641399  |
# __________________________________________________________________________________
# |    6      |    14.750000 |    14.875000 |    14.812500 |  0.421941  |  0.218536  |
# __________________________________________________________________________________
# |    7      |    14.750000 |    14.812500 |    14.781250 |  0.211416  |  0.007104  |
# __________________________________________________________________________________
# |    8      |    14.750000 |    14.781250 |    14.765625 |  0.105820  |  0.098612  |
# __________________________________________________________________________________
# |    9      |    14.765625 |    14.781250 |    14.773438 |  0.052882  |  0.045754  |
# __________________________________________________________________________________
# |    10     |    14.773438 |    14.781250 |    14.777344 |  0.026434  |  0.019325  |
#
# Valor Aproximado=  14.77734375
