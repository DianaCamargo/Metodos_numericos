# %%
import math as mt
import matplotlib
import numpy as np
n=5
es=0.5*(10**(2-n))*100 #Error tolerado
print '######Ejemplo 5.6 Chapra#####\n Metodo biseccion \n ###Diana Camargo###'
print 'f(x)=x^10  - 1' 
print 'Error Tolerado=', es, '%'
print 'ERPA=Error Relativo Porcentual Aproximado'
print ("_______________________________________________________________________________")
print "|%-5s | %-12s |   %-9s  |   %-9s  | %-9s  | %-9s  |" %('Iteraccion','    xi  ','   xu','  xr ',' ERPA (%)','ERPV (%)')
xi=0
xu=1.3
xr=0.0
fxi=0.0
fxu=0.0
vver=1  #LA RAIZ Verdadera
i=1
erpa=0.0
while(True):
    val_ante=xr
    fxi=(xi**(10))-1
    fxu=(xu**(10))-1
    xr=(xi+xu)/2
    fxr=(xr**(10))-1
    ev=vver-xr
    erpv=abs(ev/vver)*100
    erpa=abs((xr-val_ante)/(xr))*100
    
    print ("__________________________________________________________________________________")
    print"|    %-6d |    %-9f |    %-9f |    %-9f |  %-10f|  %-10f|" %(i,xi,xu,xr,erpa,erpv)
    if(fxi*fxr<0):
        xu=xr
    if(fxi*fxr>0):
        xi=xr
    if (erpa<es or fxi*fxr==0 ):
        break
    i=i+1
print '\nValor Aproximado= ',xr
# Out:
# ######Ejemplo 5.6 Chapra#####
#  Metodo biseccion
#  ###Diana Camargo###
# f(x)=x^10  - 1
# Error Tolerado= 0.05 %
# ERPA=Error Relativo Porcentual Aproximado
# _______________________________________________________________________________
# |Iteraccion |     xi       |      xu      |     xr       |  ERPA (%)  | ERPV (%)   |
# __________________________________________________________________________________
# |    1      |    0.000000  |    1.300000  |    0.650000  |  100.000000|  35.000000 |
# __________________________________________________________________________________
# |    2      |    0.650000  |    1.300000  |    0.975000  |  33.333333 |  2.500000  |
# __________________________________________________________________________________
# |    3      |    0.975000  |    1.300000  |    1.137500  |  14.285714 |  13.750000 |
# __________________________________________________________________________________
# |    4      |    0.975000  |    1.137500  |    1.056250  |  7.692308  |  5.625000  |
# __________________________________________________________________________________
# |    5      |    0.975000  |    1.056250  |    1.015625  |  4.000000  |  1.562500  |
# __________________________________________________________________________________
# |    6      |    0.975000  |    1.015625  |    0.995313  |  2.040816  |  0.468750  |
# __________________________________________________________________________________
# |    7      |    0.995313  |    1.015625  |    1.005469  |  1.010101  |  0.546875  |
# __________________________________________________________________________________
# |    8      |    0.995313  |    1.005469  |    1.000391  |  0.507614  |  0.039063  |
# __________________________________________________________________________________
# |    9      |    0.995313  |    1.000391  |    0.997852  |  0.254453  |  0.214844  |
# __________________________________________________________________________________
# |    10     |    0.997852  |    1.000391  |    0.999121  |  0.127065  |  0.087891  |
# __________________________________________________________________________________
# |    11     |    0.999121  |    1.000391  |    0.999756  |  0.063492  |  0.024414  |
# __________________________________________________________________________________
# |    12     |    0.999756  |    1.000391  |    1.000073  |  0.031736  |  0.007324  |
#
# Valor Aproximado=  1.00007324219
