# %%
import math as mt
import matplotlib
import numpy as np
-
# Out:
# ######Ejemplo 5.6 Chapra#####
#  Metodo biseccion
#  ###Diana Camargo###
# f(x)=x^10  - 1
# Error Tolerado= 0.05 %
# ERPA=Error Relativo Porcentual Aproximado
# _______________________________________________________________________________
# |Iteraccion |     xi       |      xu      |     xr       |  ERPA (%)  | ERPV (%)   |
# __________________________________________________________________________________
# |    1      |    0.000000  |    1.300000  |    0.650000  |  100.000000|  35.000000 |
# __________________________________________________________________________________
# |    2      |    0.650000  |    1.300000  |    0.975000  |  33.333333 |  2.500000  |
# __________________________________________________________________________________
# |    3      |    0.975000  |    1.300000  |    1.137500  |  14.285714 |  13.750000 |
# __________________________________________________________________________________
# ...
