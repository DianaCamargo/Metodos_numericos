# %%
import math as mt
import matplotlib
import numpy as np
n=5
es=0.5*(10**(2-n))*100 #Error tolerado
print '######Ejemplo 5.6 Chapra#####\n Metodo falsa posicion \n ###Diana Camargo###'
print 'f(x)=x^10  - 1'  
print 'Error Tolerado=', es, '%'
print 'ERPA=Error Relativo Porcentual Aproximado'
print ("_______________________________________________________________________________")
print "|%-5s | %-12s |   %-9s  |   %-9s  | %-9s  | %-9s  |" %('Iteraccion','    xi  ','   xu','  xr ',' ERPA (%)','ERPV (%)')
xi=0
xu=1.3
xr=0.0
fxi=0.0
fxu=0.0
vver=1  #LA RAIZ Verdadera
i=1
erpa=0.0
val_ante=0.0
while(True):
    val_ante=xr
    fxi=(xi**(10)) - 1
    fxu=(xu**(10)) - 1
    xr=xu-(fxu*(xi-xu)/(fxi-fxu))
    fxr=(xr**(10)) - 1
    erpa=abs((xr-val_ante)/(xr))*100
    ev=abs(vver-xr)
    erpv=abs(ev/vver)*100
    print ("__________________________________________________________________________________")
    print"|    %-6d |    %-9f |    %-9f |    %-9f |  %-10f|  %-10f|" %(i,xi,xu,xr,erpa,erpv)
    if(fxi*fxr<0):
        xu=xr
    if(fxi*fxr>0):
        xi=xr
    if (erpa<es or fxi*fxr==0):
        break
    i=i+1
print '\nValor Aproximado= ',xr
# Out:
# ######Ejemplo 5.6 Chapra#####
#  Metodo falsa posicion
#  ###Diana Camargo###
# f(x)=x^10  - 1
# Error Tolerado= 0.05 %
# ERPA=Error Relativo Porcentual Aproximado
# _______________________________________________________________________________
# |Iteraccion |     xi       |      xu      |     xr       |  ERPA (%)  | ERPV (%)   |
# __________________________________________________________________________________
# |    1      |    0.000000  |    1.300000  |    0.094300  |  100.000000|  90.570040 |
# __________________________________________________________________________________
# |    2      |    0.094300  |    1.300000  |    0.181759  |  48.118299 |  81.824113 |
# __________________________________________________________________________________
# |    3      |    0.181759  |    1.300000  |    0.262874  |  30.857040 |  73.712599 |
# __________________________________________________________________________________
# |    4      |    0.262874  |    1.300000  |    0.338105  |  22.250800 |  66.189490 |
# __________________________________________________________________________________
# |    5      |    0.338105  |    1.300000  |    0.407878  |  17.106298 |  59.212208 |
# __________________________________________________________________________________
# |    6      |    0.407878  |    1.300000  |    0.472583  |  13.691820 |  52.741685 |
# __________________________________________________________________________________
# |    7      |    0.472583  |    1.300000  |    0.532572  |  11.263907 |  46.742849 |
# __________________________________________________________________________________
# |    8      |    0.532572  |    1.300000  |    0.588145  |  9.448877  |  41.185543 |
# __________________________________________________________________________________
# |    9      |    0.588145  |    1.300000  |    0.639544  |  8.036883  |  36.045603 |
# __________________________________________________________________________________
# |    10     |    0.639544  |    1.300000  |    0.686943  |  6.900017  |  31.305683 |
# __________________________________________________________________________________
# |    11     |    0.686943  |    1.300000  |    0.730446  |  5.955710  |  26.955356 |
# __________________________________________________________________________________
# |    12     |    0.730446  |    1.300000  |    0.770099  |  5.148990  |  22.990126 |
# __________________________________________________________________________________
# |    13     |    0.770099  |    1.300000  |    0.805908  |  4.443285  |  19.409249 |
# __________________________________________________________________________________
# |    14     |    0.805908  |    1.300000  |    0.837874  |  3.815178  |  16.212611 |
# __________________________________________________________________________________
# |    15     |    0.837874  |    1.300000  |    0.866028  |  3.250906  |  13.397237 |
# __________________________________________________________________________________
# |    16     |    0.866028  |    1.300000  |    0.890457  |  2.743495  |  10.954272 |
# __________________________________________________________________________________
# |    17     |    0.890457  |    1.300000  |    0.911328  |  2.290170  |  8.867175  |
# __________________________________________________________________________________
# |    18     |    0.911328  |    1.300000  |    0.928885  |  1.890054  |  7.111533  |
# __________________________________________________________________________________
# |    19     |    0.928885  |    1.300000  |    0.943436  |  1.542381  |  5.656395  |
# __________________________________________________________________________________
# |    20     |    0.943436  |    1.300000  |    0.955334  |  1.245420  |  4.466602  |
# __________________________________________________________________________________
# |    21     |    0.955334  |    1.300000  |    0.964946  |  0.996077  |  3.505443  |
# __________________________________________________________________________________
# |    22     |    0.964946  |    1.300000  |    0.972630  |  0.790035  |  2.737031  |
# __________________________________________________________________________________
# |    23     |    0.972630  |    1.300000  |    0.978719  |  0.622185  |  2.128087  |
# __________________________________________________________________________________
# |    24     |    0.978719  |    1.300000  |    0.983510  |  0.487114  |  1.649005  |
# __________________________________________________________________________________
# |    25     |    0.983510  |    1.300000  |    0.987257  |  0.379533  |  1.274308  |
# __________________________________________________________________________________
# |    26     |    0.987257  |    1.300000  |    0.990174  |  0.294566  |  0.982637  |
# __________________________________________________________________________________
# |    27     |    0.990174  |    1.300000  |    0.992436  |  0.227915  |  0.756446  |
# __________________________________________________________________________________
# |    28     |    0.992436  |    1.300000  |    0.994184  |  0.175916  |  0.581553  |
# __________________________________________________________________________________
# |    29     |    0.994184  |    1.300000  |    0.995534  |  0.135521  |  0.446638  |
# __________________________________________________________________________________
# |    30     |    0.995534  |    1.300000  |    0.996573  |  0.104246  |  0.342749  |
# __________________________________________________________________________________
# |    31     |    0.996573  |    1.300000  |    0.997371  |  0.080096  |  0.262864  |
# __________________________________________________________________________________
# |    32     |    0.997371  |    1.300000  |    0.997985  |  0.061486  |  0.201502  |
# __________________________________________________________________________________
# |    33     |    0.997985  |    1.300000  |    0.998456  |  0.047167  |  0.154408  |
#
# Valor Aproximado=  0.998455921619
